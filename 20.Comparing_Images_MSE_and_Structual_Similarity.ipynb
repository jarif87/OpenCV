# %% [markdown]
# # Comparing Images
# * 1.Compare images using Mean Squared Error(MSE)
# * 2.Compare Images Using Structural Similarity

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage.metrics import structural_similarity
# %matplotlib inline

# %% [markdown]
# # **Mean Squared Error (MSE)**
#
# * The MSE between the two images is the sum of the squared difference between the two images. This can easily be implemented with numpy.
#
# * The lower the MSE the more similar the images are.

# %%
def mse(imageA, imageB):
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])
    return err

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


plt.figure(figsize=(15,10))

ImageA = cv2.imread('/content/fireworks.jpeg')
ImageB = cv2.imread('/content/fireworks2.jpeg')

ImageA = cv2.cvtColor(ImageA, cv2.COLOR_BGR2RGB)
ImageB = cv2.cvtColor(ImageB, cv2.COLOR_BGR2RGB)

M = np.ones(ImageA.shape, dtype="uint8") * 100
imageC = cv2.add(ImageA, M)

plt.subplot(1, 3, 1)
plt.imshow(ImageA)
plt.title("Image A")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(ImageB)
plt.title("Image B")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(imageC)
plt.title("Brightened Image")
plt.axis("off")

plt.show()

# %%
def compare(image1, image2):
  image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
  image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
  print('MSE = {:.2f}'.format(mse(image1, image2)))
  print('SS = {:.2f}'.format(structural_similarity(image1, image2)))

# %%
compare(ImageA, ImageB)
# Out:
# MSE = 2164.33
# SS = 0.47

# %%
compare(ImageA,ImageA)
# Out:
# MSE = 0.00
# SS = 1.00

# %%
compare(ImageA, imageC)
# Out:
# MSE = 9212.03
# SS = 0.49

# %%
compare(ImageB, imageC)
# Out:
# MSE = 13609.60
# SS = 0.17
